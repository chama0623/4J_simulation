# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("tmp.csv",header=None)
df = df.rename(columns={0:"step",1:"X",2:"Y",3:"Z",4:"Vx",5:"Vy",6:"Vz"})
df.head()
# Out:
#    step         X         Y         Z        Vx       Vy    Vz
# 0  0.00  0.100000  0.000000  0.000000  0.000000  0.10000  0.00
# 1  0.01  0.100000  0.001005  0.000000  0.002020  0.10000  0.02
# 2  0.02  0.100020  0.002010  0.000201  0.004040  0.09996  0.04
# 3  0.03  0.100061  0.003015  0.000603  0.006059  0.09988  0.06
# 4  0.04  0.100122  0.004018  0.001206  0.008077  0.09976  0.08

# %%
# 3Dでプロット
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(df["X"], df["Y"], df["Z"], "o-", color="#0000aa", ms=4, mew=0.5)

# 軸ラベル
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 表示
plt.show()

# %%
plt.figure (facecolor="white",figsize=(12,6))
plt.subplot(3,1,1)
plt.scatter(df["step"],df["X"])
plt.ylabel("x",fontsize=20)
plt.subplot(3,1,2)
plt.scatter(df["step"],df["Y"])
plt.ylabel("y",fontsize=20)
plt.subplot(3,1,3)
plt.scatter(df["step"],df["Z"])
plt.xlabel("time",fontsize=15)
plt.ylabel("z",fontsize=20)
# Out:
# Text(0, 0.5, 'z')
