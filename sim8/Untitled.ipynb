# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("tmp.csv",header=None)
df = df.rename(columns={0:"step",1:"I",2:"Q"})
df.head()
# Out:
#    step          I         Q
# 0     0  10.000000  0.000000
# 1     1  10.000000 -0.033350
# 2     2   9.999665 -0.066700
# 3     3   9.998994 -0.100049
# 4     4   9.997989 -0.133396

# %%
plt.figure(figsize=(6,4),dpi=200)
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
#plt.scatter(df["step"],df["y1"],label="$y_1$",s=100)
#plt.scatter(df["step"],df["y2"],label="$y_2$",marker="^",s=100)
plt.plot(df["step"],df["Q"],label="$Q$",linewidth=3)
plt.plot(df["step"],df["I"],label="$I$",linewidth=3)
plt.grid(False);
#plt.xlabel("時間$t$",fontsize=15)
#plt.ylabel("個体数",fontsize=15)
#plt.ylim(-1,20)
plt.legend(fontsize=15)
#plt.savefig("ex2-3.png",bbox_inches='tight')
