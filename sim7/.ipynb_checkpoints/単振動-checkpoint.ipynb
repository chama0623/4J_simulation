# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("harmonic.csv",header = None)
df = df.rename(columns={0:"step",1:"y",2:"v"})
df.head()
# Out:
#    step          y        v
# 0  0.01  10.000000 -0.20000
# 1  0.02   9.998000 -0.40000
# 2  0.03   9.994000 -0.59996
# 3  0.04   9.988000 -0.79984
# 4  0.05   9.980002 -0.99960

# %%
k = 4
tscale = np.linspace(0,10,len(df))
ycos = 10*np.cos(np.sqrt(k)*tscale)
plt.figure(facecolor="white",figsize=(6,4),dpi=200)
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.plot(df["step"],df["y"],linewidth=2,label="計算値")
plt.plot(tscale,ycos,linestyle="dashed",linewidth=2,label="理論値")
plt.xlabel("t",fontsize=15)
plt.ylabel("y",fontsize=15)
plt.legend(fontsize=13)
plt.savefig("harmonic.png",bbox_inches='tight')

# %% [markdown]
# h = 0.1 ダメ
# h = 0.25 ダメ
# h = 0.05 ダメ
# h = 0.025 ダメ
# h = 0.02 ダメ
# h = 0.015 微妙
# h = 0.01 ok
