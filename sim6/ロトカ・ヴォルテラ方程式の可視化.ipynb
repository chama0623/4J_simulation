# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-whitegrid")
import matplotlib as mpl
mpl.rcParams['font.family']='IPAexGothic'

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("tmp.csv",header=None)
df = df.rename(columns={0:"step",1:"y1",2:"y2"})
df.head()
# Out:
#    step         y1         y2
# 0   0.0  10.000000  10.000000
# 1   0.1   9.800000  10.200000
# 2   0.2   9.586360  10.391760
# 3   0.3   9.360833  10.573805
# 4   0.4   9.125275  10.744730

# %%
plt.plot(df["step"],df["y1"])
plt.plot(df["step"],df["y2"])

# %% [markdown]
# !?
