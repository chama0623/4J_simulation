# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-whitegrid")
import matplotlib as mpl
mpl.rcParams['font.family']='IPAexGothic'

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("tmp.csv",header=None)
df = df.rename(columns={0:"step",1:"y1",2:"y2"})
df.head()
# Out:
#    step         y1         y2
# 0  0.00  10.000000  10.000000
# 1  0.01  10.300000   9.900000
# 2  0.02  10.614150   9.806940
# 3  0.03  10.942820   9.720916
# 4  0.04  11.286375   9.642037

# %%
plt.figure(figsize=(6,4),dpi=200)
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
#plt.scatter(df["step"],df["y1"],label="$y_1$",s=100)
#plt.scatter(df["step"],df["y2"],label="$y_2$",marker="^",s=100)
plt.plot(df["step"],df["y1"],label="$y_1$",linewidth=3)
plt.plot(df["step"],df["y2"],label="$y_2$",linewidth=3)
plt.grid(False);
plt.xlabel("時間$t$",fontsize=15)
plt.ylabel("個体数",fontsize=15)
#plt.ylim(-1,20)
plt.legend(fontsize=15)
plt.savefig("ex2-3.png",bbox_inches='tight')
