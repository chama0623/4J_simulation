# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("tmp.csv",header=None)
df = df.rename(columns={0:"step",1:"X",2:"Y",3:"Vx",4:"Vy",5:"V"})
df.head()
# Out:
#     step         X       Y        Vx        Vy     V
# 0  0.000  0.100000  0.0000  0.000000  0.100000  0.01
# 1  0.001  0.100000  0.0001  0.000200  0.100000  0.01
# 2  0.002  0.100000  0.0002  0.000400  0.100000  0.01
# 3  0.003  0.100001  0.0003  0.000601  0.099999  0.01
# 4  0.004  0.100001  0.0004  0.000801  0.099998  0.01

# %%
plt.figure(figsize=(6,4),facecolor="white")
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
#plt.scatter(df["step"],df["y1"],label="$y_1$",s=100)
#plt.scatter(df["step"],df["y2"],label="$y_2$",marker="^",s=100)
plt.plot(df["X"],df["Y"],linewidth=5)
#plt.plot(df["step"],df["Y"],label="$Y$",linewidth=3)
plt.grid(False);
#plt.xlabel("時間$t$",fontsize=15)
#plt.ylabel("個体数",fontsize=15)
#plt.ylim(-1,20)
#plt.legend(fontsize=15)
#plt.savefig("ex2-3.png",bbox_inches='tight')

# %%
df["V"].describe()
# Out:
# count    10001.000000
# mean         0.010213
# std          0.000118
# min          0.010000
# 25%          0.010119
# 50%          0.010208
# 75%          0.010313
# max          0.010425
# Name: V, dtype: float64

# %%
plt.figure(facecolor="white",dpi=100)
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.plot(df["step"],df["V"],"|v|")
plt.plot([-1,11],[0.01,0.01]) # 真の値を描画
plt.xlabel("時間$t$",fontsize=15)
plt.xlim(0,10)
plt.ylabel("|v|",fontsize=15)
# Out:
# Text(0, 0.5, '|v|')
