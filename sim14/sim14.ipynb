# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./result.csv",header=None)
df = df.rename(columns={0:"N",1:"result"})
df.head()
# Out:
#       N       result
# 0  1000   828.319407
# 1  1100   890.872741
# 2  1200  1011.043852
# 3  1300  1000.867556
# 4  1400  1101.362519

# %%
xscale = np.arange(0,5600,100)
slope1 =0.827728
intercept1 =  -41.229717

slope1 = round(slope1,2)
intercept1 = round(intercept1,2)
yscale = xscale*slope1 + intercept1

plt.figure(facecolor="white",dpi=100)
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.scatter(df["N"],df["result"])
plt.plot(xscale,yscale,label="y= "+str(slope1)+" x + "+str(intercept1),c="r")
plt.xlabel("ステップ数$N$",fontsize=15)
plt.ylabel("分散$V$",fontsize=15)
plt.xlim(500,5500)
plt.legend()
plt.savefig("p07.png",bbox_inches='tight')
